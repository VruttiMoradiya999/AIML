# %%
import pandas as pd

# %%
data = {
    'Name' : ['Vruti', 'Krishna', 'Urvashi', 'Lendaa'],
    'Age' : [ 34, 33, 64, 56],
    'City' : ['suradwt', 'dwfwhj', 'ewgrwg', 'ewfre']
    }
pd.DataFrame(data)
# Out:
#       Name  Age     City
# 0    Vruti   34  suradwt
# 1  Krishna   33   dwfwhj
# 2  Urvashi   64   ewgrwg
# 3   Lendaa   56    ewfre

# %%
data["wish"] = ["Nothing", "Lambo", "Boyfriend", "idk"]

# %%
pd.DataFrame(data)
# Out:
#       Name  Age     City       wish
# 0    Vruti   34  suradwt    Nothing
# 1  Krishna   33   dwfwhj      Lambo
# 2  Urvashi   64   ewgrwg  Boyfriend
# 3   Lendaa   56    ewfre        idk

# %%
dff = pd.DataFrame(data)
print(dff)
# Out:
#       Name  Age     City       wish
# 0    Vruti   34  suradwt    Nothing
# 1  Krishna   33   dwfwhj      Lambo
# 2  Urvashi   64   ewgrwg  Boyfriend
# 3   Lendaa   56    ewfre        idk

# %%
print(dff.loc[[2,3]]["City"])
# Out:
# 2    ewgrwg
# 3     ewfre
# Name: City, dtype: object

# %%
dff.drop('wish', axis = 1)
# Out:
#       Name  Age     City
# 0    Vruti   34  suradwt
# 1  Krishna   33   dwfwhj
# 2  Urvashi   64   ewgrwg
# 3   Lendaa   56    ewfre

# %%
dff[(dff["Age"]> 60) & (dff["Name"] == 'Urvashi')]
# Out:
#       Name  Age    City       wish
# 2  Urvashi   64  ewgrwg  Boyfriend

# %%
import numpy as np
import pandas as pd

# %%
data = {
    'category' : ['A', 'B', 'A', 'B'],
    'Store' : ['S1', 'S2', 'S3', 'S4'],
    'Sales' : [100, 200, 300, 400],
    'Date' : pd.date_range('2026-07-02', periods=4)
}
df = pd.DataFrame(data)

# %%
df
# Out:
#   category Store  Sales       Date
# 0        A    S1    100 2026-07-02
# 1        B    S2    200 2026-07-03
# 2        A    S3    300 2026-07-04
# 3        B    S4    400 2026-07-05

# %%
c= df.groupby('category')

# %%
c

# %%
for i , v in c :
    print(i)
    print(v)
# Out:
# A
#   category Store  Sales       Date
# 0        A    S1    100 2026-07-02
# 2        A    S3    300 2026-07-04
# B
#   category Store  Sales       Date
# 1        B    S2    200 2026-07-03
# 3        B    S4    400 2026-07-05

# %%
c= df.groupby('category')['Sales'].sum()
c
# Out:
# category
# A    400
# B    600
# Name: Sales, dtype: int64

# %%
df.shape

# %%
df.columns

# %%
df.info()

# %%
df.describe()

# %%
df['A']+ 10
